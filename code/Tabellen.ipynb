# %% [markdown]
# # ESEF-Berichterstattung in Deutschland: Herausforderungen und Chancen
#
# ## Der Python-Code zum Replizieren der Tabellen 1–3
#
# Das Jupyter-Notebook befindet sich unter: https://github.com/esefpaper/onlineappendix/blob/main/code/Tabellen.ipynb

# %%
# !pip install --force-reinstall numpy==2.2.4 pandas==2.2.3
# !pip install openpyxl
# Out:
# Collecting numpy==2.2.4
#   Downloading numpy-2.2.4-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.0 MB/s eta 0:00:00
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.9 MB/s eta 0:00:00
# Collecting python-dateutil>=2.8.2 (from pandas==2.2.3)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.2.3)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.3)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.2.3)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading numpy-2.2.4-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 27.4 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 26.5 MB/s eta 0:00:0000:0100:01
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 17.1 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 21.3 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 22.4 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.1
#     Uninstalling pytz-2025.1:
#       Successfully uninstalled pytz-2025.1
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformer-smaller-training-vocab 0.4.0 requires numpy<2.0.0,>=1.21.0; python_version >= "3.9", but you have numpy 2.2.4 which is incompatible.
# langchain 0.3.14 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.2.4 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.4 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.
# hdbscan 0.8.33 requires cython<3,>=0.27, but you have cython 3.0.12 which is incompatible.
# datashaper 0.0.49 requires pyarrow<16.0.0,>=15.0.0, but you have pyarrow 19.0.1 which is incompatible.
# deutschland 0.4.2 requires lxml<5.0.0,>=4.9.3, but you have lxml 5.3.1 which is incompatible.
# deutschland 0.4.2 requires numpy<2.0.0,>=1.19.0; python_version >= "3.8" and python_version < "3.12", but you have numpy 2.2.4 which is incompatible.
# docling-core 2.5.1 requires pydantic<2.10,>=2.6.0, but you have pydantic 2.10.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.5 which is incompatible.
# flet 0.23.2 requires packaging<24.0,>=23.1, but you have packaging 24.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.4 which is incompatible.
# pix2tex 0.1.3 requires timm==0.5.4, but you have timm 0.9.16 which is incompatible.
# tensorflow-macos 2.16.2 requires tensorflow==2.16.2; platform_system == "Darwin" and platform_machine == "arm64", but you have tensorflow 2.19.0 which is incompatible.
# browser-use 0.1.36 requires markdownify==0.14.1, but you have markdownify 0.13.1 which is incompatible.
# vllm 0.8.1 requires numpy<2.0.0, but you have numpy 2.2.4 which is incompatible.
# langchain-aws 0.2.12 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.2.4 which is incompatible.
# graspologic 3.4.1 requires numpy<2.0.0,>=1.26.4, but you have numpy 2.2.4 which is incompatible.
# graspologic 3.4.1 requires scipy==1.12.0, but you have scipy 1.15.2 which is incompatible.
# pylance 0.13.0 requires pyarrow<15.0.1,>=12, but you have pyarrow 19.0.1 which is incompatible.
# datasets 3.4.1 requires fsspec[http]<=2024.12.0,>=2023.1.0, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed numpy-2.2.4 pandas-2.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2

# %%
import pandas as pd
import re

# %%
import os
os.makedirs("../results", exist_ok=True)

# %% [markdown]
# ### Tabelle 1
#
# Tabelle 1 zeigt die ESEF-Konformitätsraten deut-scher kapitalmarktorientierter Unternehmen über den Beobachtungszeitraum von 2020 bis 2023.

# %%
tb1_uregdw_s5 = pd.read_pickle("../data/tb1_uregdw_s5_20250616.p.gz")

# %%
def create_tb1_panel(df, byvar, ascending =True):
    # Group by the specified variable
    tb1_de_rows = df.groupby([byvar]).gvkey.nunique().reset_index().rename(columns={"gvkey": "gvkey_nunique"})
    
    # Create the different groupings
    tb1c_01 = df.groupby([byvar]).gvkey.count().reset_index()
    tb1c_02 = df.loc[df.sum_filing_score>=8].groupby([byvar]).gvkey.count().reset_index()
    tb1c_03 = df.loc[df.sum_filing_score>=16].groupby([byvar]).gvkey.count().reset_index()
    tb1c_04 = df.loc[df.sum_filing_score>=32768].groupby([byvar]).gvkey.count().reset_index()
    
    # Merge all the data
    result = pd.merge(tb1_de_rows, tb1c_01, on=byvar, how="left", suffixes=("", "")).fillna(0)
    result = pd.merge(result, tb1c_02, on=byvar, how="left", suffixes=("", "_esef")).fillna(0)
    result["anteil_esef"] = result["gvkey_esef"]/result["gvkey"]
    result["anteil_esef"] = result["anteil_esef"].apply(lambda x: round(x*100, 1))
    
    result = pd.merge(result, tb1c_03, on=byvar, how="left", suffixes=("", "_xbrl")).fillna(0)
    result["anteil_xbrl"] = result["gvkey_xbrl"]/result["gvkey"]
    result["anteil_xbrl"] = result["anteil_xbrl"].apply(lambda x: round(x*100, 1))
    
    result = pd.merge(result, tb1c_04, on=byvar, how="left", suffixes=("", "_complete")).fillna(0)
    result["anteil_complete"] = result["gvkey_complete"]/result["gvkey"]
    result["anteil_complete"] = result["anteil_complete"].apply(lambda x: round(x*100, 1))
    
    result.fillna(0, inplace=True)
    result.sort_values(by=byvar, ascending=ascending, inplace=True)
    result.to_excel(f"../results/tb1_by{byvar}.xlsx")
    return result

# %%
# Panel A
tb1_by_formyear = create_tb1_panel(tb1_uregdw_s5, "formyear")
tb1_by_formyear
# Out:
#    formyear  gvkey_nunique  gvkey  gvkey_esef  anteil_esef  gvkey_xbrl  \
# 0      2020            596    596         354         59.4         330
# 1      2021            595    595         410         68.9         405
# 2      2022            572    572         397         69.4         392
# 3      2023            492    492         368         74.8         362
#
#    anteil_xbrl  gvkey_complete  anteil_complete
# 0         55.4             317             53.2
# 1         68.1             362             60.8
# 2         68.5             355             62.1
# 3         73.6             330             67.1

# %%
# table 1 2020--2023 ESEF Sample period
tb1_uregdw_s5["2020--2023"] = tb1_uregdw_s5.formyear.apply(lambda x: True if x>=2020 & x<=2024 else False)

byvar = "2020--2023"
tb1_esef = create_tb1_panel(tb1_uregdw_s5, byvar, ascending=False)
tb1_esef
# Out:
#    2020--2023  gvkey_nunique  gvkey  gvkey_esef  anteil_esef  gvkey_xbrl  \
# 0        True            610   2255        1529         67.8        1489
#
#    anteil_xbrl  gvkey_complete  anteil_complete
# 0         66.0            1364             60.5

# %%
byvar = "FSE_Label"
tb1_by_FSE_label = create_tb1_panel(tb1_uregdw_s5, byvar)
tb1_by_FSE_label
# Out:
#                            FSE_Label  gvkey_nunique  gvkey  gvkey_esef  \
# 0                           1. DAX40             42    163         157
# 1                  2. Prime Standard            208    806         707
# 2                             3. SME             82    299         220
# 3  4. Aktuell nicht als Aktie an FWB            282    987         445
#
#    anteil_esef  gvkey_xbrl  anteil_xbrl  gvkey_complete  anteil_complete
# 0         96.3         157         96.3             155             95.1
# 1         87.7         701         87.0             681             84.5
# 2         73.6         213         71.2             186             62.2
# 3         45.1         418         42.4             342             34.7

# %%
tb1_uregdw_s5["DE_ISIN"] = tb1_uregdw_s5["isin"].str.startswith("DE")
tb1_uregdw_s5["DE_ISIN"] = tb1_uregdw_s5["DE_ISIN"].fillna(True)

byvar = "DE_ISIN"
tb1_de_isin = create_tb1_panel(tb1_uregdw_s5, byvar, ascending=False)
tb1_de_isin
# Out:
# /var/folders/mz/hx4rhsms565c3zkfh7qx8xs00000gn/T/ipykernel_43243/187706699.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tb1_uregdw_s5["DE_ISIN"] = tb1_uregdw_s5["DE_ISIN"].fillna(True)
#    DE_ISIN  gvkey_nunique  gvkey  gvkey_esef  anteil_esef  gvkey_xbrl  \
# 1     True            590   2189        1492         68.2        1452
# 0    False             20     66          37         56.1          37
#
#    anteil_xbrl  gvkey_complete  anteil_complete
# 1         66.3            1330             60.8
# 0         56.1              34             51.5

# %%
byvar = "mcap_g4"
tb1_de_mcap_beg = create_tb1_panel(tb1_uregdw_s5, byvar, ascending=False)
tb1_de_mcap_beg
# Out:
#   mcap_g4  gvkey_nunique  gvkey  gvkey_esef  anteil_esef  gvkey_xbrl  \
# 3   MCap4            160    528         360         68.2         353
# 2   MCap3            159    476         359         75.4         357
# 1   MCap2            219    661         433         65.5         420
# 0   MCap1            186    590         377         63.9         359
#
#    anteil_xbrl  gvkey_complete  anteil_complete
# 3         66.9             312             59.1
# 2         75.0             342             71.8
# 1         63.5             380             57.5
# 0         60.8             330             55.9

# %%
byvar = "gsec_type"
tb1_de_mcap_beg = create_tb1_panel(tb1_uregdw_s5, byvar, ascending=True)
tb1_de_mcap_beg
# Out:
#                        gsec_type  gvkey_nunique  gvkey  gvkey_esef  \
# 0                     10 Energie              7     26          13
# 1        15 Roh- und Grundstoffe             32    115          94
# 2                   20 Industrie            136    519         398
# 3   25 Verbraucher Diskretionäre             90    329         223
# 4         30 Verbraucher Staples             25     92          44
# 5            35 Gesundheitswesen             61    222         145
# 6                    40 Finanzen             53    206         160
# 7     45 Informationstechnologie            109    386         201
# 8           50 Telekommunikation             46    167         111
# 9           55 Energieversorgung             16     61          42
# 10                 60 Immobilien             32    122          98
#
#     anteil_esef  gvkey_xbrl  anteil_xbrl  gvkey_complete  anteil_complete
# 0          50.0          13         50.0              12             46.2
# 1          81.7          89         77.4              77             67.0
# 2          76.7         395         76.1             373             71.9
# 3          67.8         218         66.3             196             59.6
# 4          47.8          44         47.8              44             47.8
# 5          65.3         135         60.8             124             55.9
# 6          77.7         152         73.8             126             61.2
# 7          52.1         200         51.8             194             50.3
# 8          66.5         108         64.7             101             60.5
# 9          68.9          41         67.2              36             59.0
# 10         80.3          94         77.0              81             66.4

# %% [markdown]
# ### Tabelle 2
#
# Tabelle 2 analysiert die Verwendung von Standard-IFRS-Taxonomie-Tags und firmenspezifischen Erweiterungstags in den ESEF-Berichten. Es ist zu beachten, dass die Methodik das Zählen der Anzahl der Konzepte unter der XBRL-Taxonomie umfasst, nicht jedoch die Anzahl der Fakten.

# %%
data_tb2 = pd.read_pickle("../data/data_tb2_20250616.p.gz", compression="gzip")
data_tb2i = pd.read_pickle("../data/data_tb2i_20250616.p.gz", compression="gzip")

# %%
def create_tb2_panel(data_tb2, byvar, ascending=True):
    # Group by the specified variable
    tb2a_rows = data_tb2.groupby([byvar]).gvkey.nunique().reset_index().rename(columns={"gvkey": "gvkey_nunique"})

    tb2a_01 = data_tb2.groupby([byvar, "gvkey"]).concept_name.nunique().reset_index().groupby(byvar).concept_name.mean().apply(lambda x: round(x, 1)).reset_index()
    tb2a_02 = data_tb2.loc[ ~data_tb2.concept_is_extended].groupby([byvar, "gvkey"]).concept_name.nunique().reset_index().groupby(byvar).concept_name.mean().apply(lambda x: round(x, 1)).reset_index()
    tb2a_03 = data_tb2.loc[ data_tb2.concept_is_extended].groupby([byvar, "gvkey"]).concept_name.nunique().reset_index().groupby(byvar).concept_name.mean().apply(lambda x: round(x, 1)).reset_index()

    tb2a = pd.merge(tb2a_01, tb2a_02, on=byvar, how="left", suffixes=("", "_ifrs")).fillna(0)
    tb2a = pd.merge(tb2a, tb2a_03, on=byvar, how="left", suffixes=("", "_erw")).fillna(0)

    tb2a.fillna(0, inplace=True)
    tb2a["concept_name"] = tb2a["concept_name_ifrs"] + tb2a["concept_name_erw"]
    tb2a["anteil_ifrs"] = tb2a["concept_name_ifrs"]/tb2a["concept_name"]
    tb2a["anteil_ifrs"] = tb2a["anteil_ifrs"].apply(lambda x: round(x*100, 1))

    tb2a["anteil_erw"] = tb2a["concept_name_erw"]/tb2a["concept_name"]
    tb2a["anteil_erw"] = tb2a["anteil_erw"].apply(lambda x: round(x*100, 1))


    tb2a.sort_values(by=byvar, ascending=ascending, inplace=True)
    tb2a.to_excel(f"../results/tb2_{byvar}.xlsx")
    tb2a

    return tb2a

# %%
#formyear
tb2_by_formyear = create_tb2_panel(data_tb2, "formyear")
tb2_by_formyear
# Out:
#    formyear  concept_name  concept_name_ifrs  concept_name_erw  anteil_ifrs  \
# 0      2020         142.8              127.8              15.0         89.5
# 1      2021         143.8              128.5              15.3         89.4
# 2      2022         266.8              251.7              15.1         94.3
# 3      2023         282.5              267.8              14.7         94.8
#
#    anteil_erw
# 0        10.5
# 1        10.6
# 2         5.7
# 3         5.2

# %%
#statement_type / TagType
tb2_by_statement_type = create_tb2_panel(data_tb2i, "statement_type")
tb2_by_statement_type
# Out:
#                statement_type  concept_name  concept_name_ifrs  \
# 0                  0. General           2.3                2.3
# 1                   1. Bilanz          42.7               35.7
# 2                      2. GuV          25.5               19.9
# 3                  3. GKV/UKV          17.7               12.9
# 4     4. Kapitalflussrechnung          34.5               24.0
# 5  5. EK-Veränderungsrechnung          20.6               16.1
# 6   6. Nettovermögensänderung           1.0                1.0
# 7                   7. Anhang         164.7              160.1
#
#    concept_name_erw  anteil_ifrs  anteil_erw
# 0               0.0        100.0         0.0
# 1               7.0         83.6        16.4
# 2               5.6         78.0        22.0
# 3               4.8         72.9        27.1
# 4              10.5         69.6        30.4
# 5               4.5         78.2        21.8
# 6               0.0        100.0         0.0
# 7               4.6         97.2         2.8

# %%
#FSE_Label
tb2_by_FSE_Label = create_tb2_panel(data_tb2, "FSE_Label")
tb2_by_FSE_Label
# Out:
#                            FSE_Label  concept_name  concept_name_ifrs  \
# 0                           1. DAX40         364.6              316.8
# 1                  2. Prime Standard         308.4              284.9
# 2                             3. SME         263.0              243.5
# 3  4. Aktuell nicht als Aktie an FWB         266.9              242.0
#
#    concept_name_erw  anteil_ifrs  anteil_erw
# 0              47.8         86.9        13.1
# 1              23.5         92.4         7.6
# 2              19.5         92.6         7.4
# 3              24.9         90.7         9.3

# %%
#DE_ISIN
data_tb2["DE_ISIN"] = data_tb2["isin"].str.startswith("DE")
tb2_by_gsec_type = create_tb2_panel(data_tb2, "DE_ISIN", ascending=False)
tb2_by_gsec_type
# Out:
#    DE_ISIN  concept_name  concept_name_ifrs  concept_name_erw  anteil_ifrs  \
# 1     True         309.3              283.3              26.0         91.6
# 0    False         287.4              258.8              28.6         90.0
#
#    anteil_erw
# 1         8.4
# 0        10.0

# %%
#mcap_g4
tb2_by_mcap_g4 = create_tb2_panel(data_tb2, "mcap_g4", ascending=False)
tb2_by_mcap_g4
# Out:
#   mcap_g4  concept_name  concept_name_ifrs  concept_name_erw  anteil_ifrs  \
# 3   MCap4         302.4              266.7              35.7         88.2
# 2   MCap3         284.7              262.7              22.0         92.3
# 1   MCap2         261.0              242.3              18.7         92.8
# 0   MCap1         261.0              243.8              17.2         93.4
#
#    anteil_erw
# 3        11.8
# 2         7.7
# 1         7.2
# 0         6.6

# %%
#gsec_type
tb2_by_gsec_type = create_tb2_panel(data_tb2, "gsec_type")
tb2_by_gsec_type
# Out:
#                        gsec_type  concept_name  concept_name_ifrs  \
# 0                     10 Energie         320.3              282.5
# 1        15 Roh- und Grundstoffe         325.3              296.3
# 2                   20 Industrie         305.3              280.8
# 3   25 Verbraucher Diskretionäre         281.3              258.9
# 4         30 Verbraucher Staples         305.6              279.7
# 5            35 Gesundheitswesen         291.2              267.6
# 6                    40 Finanzen         322.6              274.2
# 7     45 Informationstechnologie         279.3              263.6
# 8           50 Telekommunikation         270.3              254.1
# 9           55 Energieversorgung         323.1              280.7
# 10                 60 Immobilien         297.2              262.2
#
#     concept_name_erw  anteil_ifrs  anteil_erw
# 0               37.8         88.2        11.8
# 1               29.0         91.1         8.9
# 2               24.5         92.0         8.0
# 3               22.4         92.0         8.0
# 4               25.9         91.5         8.5
# 5               23.6         91.9         8.1
# 6               48.4         85.0        15.0
# 7               15.7         94.4         5.6
# 8               16.2         94.0         6.0
# 9               42.4         86.9        13.1
# 10              35.0         88.2        11.8

# %% [markdown]
# ### Tabelle 3
#
# Tabelle 3 analysiert die Verwendung von XBRL-Markierungen im Anhang zum Jahresabschluss. Sie zeigt die Anzahl der Unternehmen und Berichte, die bestimmte Anhangangaben taggen, sowie die durchschnittliche Anzahl der Tags pro Anhangang-abe und den Anteil der Text- und Zahlentags.

# %%
data_tb2i["reportkey"] = data_tb2i.gvkey.astype(str)+data_tb2i.formyear.astype(str)
data_tb3 = data_tb2i.loc[data_tb2i.statement_type=="7. Anhang"].copy()

# %%
byvar = "TopConcept"
tb2a_01 = data_tb3.groupby(["TopConcept", "gvkey"]).concept_name.nunique().reset_index().groupby("TopConcept").concept_name.mean().apply(lambda x: round(x, 1)).reset_index()
tb2a_01.head(10)
# Out:
#                                           TopConcept  concept_name
# 0  [800100] Notes - Subclassifications of assets,...          10.9
# 1    [800200] Notes - Analysis of income and expense           3.9
# 2  [800300] Notes - Statement of cash flows, addi...           8.0
# 3  [800400] Notes - Statement of changes in equit...           2.6
# 4                     [800500] Notes - List of notes          85.5
# 5  [800610] Notes - List of material accounting p...          49.1
# 6  [810000] Notes - Corporate information and sta...          10.7
# 7  [811000] Notes - Accounting policies, changes ...           1.7
# 8       [813000] Notes - Interim financial reporting           1.0
# 9     [815000] Notes - Events after reporting period           2.0

# %%
data_tb3["type_notetag_text"] = data_tb3.Type_y.astype(str).str.contains("Text|Abstract|Axis|Disclsoure|Lineitems|Textblock")
data_tb3.type_notetag_text = data_tb3.type_notetag_text.fillna(True)
data_tb3.loc[data_tb3.TopType.fillna("").str.contains("800500|800610")].type_notetag_text.value_counts()

tb2a_02 = data_tb3.loc[ ~data_tb3.type_notetag_text].groupby([byvar, "gvkey"]).concept_name.nunique().reset_index().groupby(byvar).concept_name.mean().apply(lambda x: round(x, 1)).reset_index()

# %%
tb3_firms = data_tb3.groupby(["TopConcept"]).gvkey.nunique().reset_index().rename(columns={"gvkey": "nfirms"})
tb3_reportkeys = data_tb3.groupby(["TopConcept"]).reportkey.nunique().reset_index().rename(columns={"reportkey": "nreports"})
tb3_rows = pd.merge(tb3_firms, tb3_reportkeys, on="TopConcept", how="left", suffixes=("", "_")).fillna(0)

tb3_rows = pd.merge(tb3_rows, tb2a_01, on="TopConcept", how="left", suffixes=("", "")).fillna(0)
tb3_rows = pd.merge(tb3_rows, tb2a_02, on="TopConcept", how="left", suffixes=("", "_num")).fillna(0)
tb3_rows.sort_values(by="nreports", ascending=False, inplace=True)

# %%
tb2a_03 = data_tb3.loc[ data_tb3.type_notetag_text].groupby([byvar, "gvkey"]).concept_name.nunique().reset_index().groupby(byvar).concept_name.mean().apply(lambda x: round(x, 1)).reset_index()

tb3 = pd.merge(tb3_rows, tb2a_03, on="TopConcept", how="left", suffixes=("", "_text")).fillna(0)

tb3.fillna(0, inplace=True)
tb3.head(10)
# Out:
#                                           TopConcept  nfirms  nreports  \
# 0  [810000] Notes - Corporate information and sta...     410      1357
# 1  [800100] Notes - Subclassifications of assets,...     410      1353
# 2  [800300] Notes - Statement of cash flows, addi...     404      1320
# 3    [800200] Notes - Analysis of income and expense     370      1204
# 4  [800400] Notes - Statement of changes in equit...     382      1182
# 5                     [800500] Notes - List of notes     359       648
# 6  [800610] Notes - List of material accounting p...     359       648
# 7                            [832610] Notes - Leases     200       621
# 8               [851100] Notes - Cash flow statement     162       418
# 9             [822390] Notes - Financial instruments      69       157
#
#    concept_name  concept_name_num  concept_name_text
# 0          10.7               2.4                9.4
# 1          10.9              10.8                1.5
# 2           8.0               8.0                0.0
# 3           3.9               3.9                1.5
# 4           2.6               2.6                1.0
# 5          85.5               0.0               85.5
# 6          49.1               0.0               49.1
# 7           2.1               2.1                1.6
# 8           1.6               1.5                1.2
# 9           1.3               1.2                1.2

# %%
tb3["concept_name"] = tb3["concept_name_text"] + tb3["concept_name_num"]

tb3["anteil_num"] = tb3["concept_name_num"]/tb3["concept_name"]
tb3["anteil_num"] = tb3["anteil_num"].apply(lambda x: round(x*100, 1))
tb3["anteil_text"] = tb3["concept_name_text"]/tb3["concept_name"]
tb3["anteil_text"] = tb3["anteil_text"].apply(lambda x: round(x*100, 1))

tb3["TopConcept"] = tb3["TopConcept"].apply(lambda x: re.sub("^\[\d{6}\]\s?","", str(x)))

tb3.sort_values(by="nreports", ascending=False, inplace=True)
tb3[["TopConcept", "nfirms", "nreports", "concept_name", "concept_name_text", "anteil_text", "concept_name_num",  "anteil_num"]].to_excel(f"../results/tb3_TopConcept.xlsx")
tb3[["TopConcept", "nfirms", "nreports", "concept_name", "concept_name_text", "anteil_text", "concept_name_num",  "anteil_num"]]
# Out:
#                                            TopConcept  nfirms  nreports  \
# 0   Notes - Corporate information and statement of...     410      1357
# 1   Notes - Subclassifications of assets, liabilit...     410      1353
# 2   Notes - Statement of cash flows, additional di...     404      1320
# 3              Notes - Analysis of income and expense     370      1204
# 4   Notes - Statement of changes in equity, additi...     382      1182
# 5                               Notes - List of notes     359       648
# 6   Notes - List of material accounting policy inf...     359       648
# 7                                      Notes - Leases     200       621
# 8                         Notes - Cash flow statement     162       418
# 9                       Notes - Financial instruments      69       157
# 10  Notes - Non-current asset held for sale and di...      62       131
# 11                               Notes - Income taxes      41       126
# 12                         Notes - Earnings per share      51       121
# 13  Notes - Effects of changes in foreign exchange...      35       110
# 14      Notes - Revenue from contracts with customers      29        72
# 15                        Notes - Investment property      26        71
# 16                          Notes - Employee benefits      22        52
# 17                      Notes - Business combinations      27        51
# 18                Notes - Interests in other entities      25        50
# 19  Notes - Share capital, reserves and other equi...      16        32
# 20                          Notes - Intangible assets      15        31
# 21  Notes - Accounting policies, changes in accoun...      21        28
# 22                         Notes - Operating segments      11        22
# 23                       Notes - Impairment of assets      10        18
# 24                              Notes - Related party      10        16
# 25  Notes - Other provisions, contingent liabiliti...       8        15
# 26              Notes - Property, plant and equipment       8        13
# 27           Notes - Share-based payment arrangements       6        11
# 28                     Notes - Additional information       6        10
# 30              Notes - Insurance contracts (IFRS 17)       8         8
# 29                     Notes - Fair value measurement       7         8
# 31                Notes - Interim financial reporting       2         6
# 32  Notes - Analysis of other comprehensive income...       1         4
# 33                        Notes - First time adoption       2         4
# 34                          Notes - Government grants       1         3
# 35              Notes - Separate financial statements       1         3
# 36                            Notes - Borrowing costs       2         2
# 37  Notes - Exploration for and evaluation of mine...       1         2
# 38                                Notes - Inventories       1         2
# 39              Notes - Events after reporting period       1         1
#
#     concept_name  concept_name_text  anteil_text  concept_name_num  anteil_num
# 0           11.8                9.4         79.7               2.4        20.3
# 1           12.3                1.5         12.2              10.8        87.8
# 2            8.0                0.0          0.0               8.0       100.0
# 3            5.4                1.5         27.8               3.9        72.2
# 4            3.6                1.0         27.8               2.6        72.2
# 5           85.5               85.5        100.0               0.0         0.0
# 6           49.1               49.1        100.0               0.0         0.0
# 7            3.7                1.6         43.2               2.1        56.8
# 8            2.7                1.2         44.4               1.5        55.6
# 9            2.4                1.2         50.0               1.2        50.0
# 10           5.6                1.2         21.4               4.4        78.6
# 11           2.8                1.0         35.7               1.8        64.3
# 12           2.7                1.0         37.0               1.7        63.0
# 13           2.1                1.0         47.6               1.1        52.4
# 14           2.2                1.1         50.0               1.1        50.0
# 15           4.4                1.8         40.9               2.6        59.1
# 16           3.2                2.2         68.8               1.0        31.2
# 17           2.0                1.0         50.0               1.0        50.0
# 18           2.3                1.3         56.5               1.0        43.5
# 19           2.6                1.2         46.2               1.4        53.8
# 20           2.2                1.2         54.5               1.0        45.5
# 21           2.6                1.6         61.5               1.0        38.5
# 22           2.3                1.3         56.5               1.0        43.5
# 23           2.0                1.0         50.0               1.0        50.0
# 24           2.2                1.2         54.5               1.0        45.5
# 25           2.0                1.0         50.0               1.0        50.0
# 26           2.0                1.0         50.0               1.0        50.0
# 27           2.0                1.0         50.0               1.0        50.0
# 28           2.0                1.0         50.0               1.0        50.0
# 30           3.2                1.0         31.2               2.2        68.8
# 29           2.5                1.5         60.0               1.0        40.0
# 31           1.0                0.0          0.0               1.0       100.0
# 32           2.0                1.0         50.0               1.0        50.0
# 33           1.0                0.0          0.0               1.0       100.0
# 34           1.0                0.0          0.0               1.0       100.0
# 35           1.0                1.0        100.0               0.0         0.0
# 36           1.0                0.0          0.0               1.0       100.0
# 37           1.0                0.0          0.0               1.0       100.0
# 38           1.0                1.0        100.0               0.0         0.0
# 39           2.0                1.0         50.0               1.0        50.0
